# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import io
import requests
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Fetching the data

# %%
# Fetch the data 
url = "https://play.minio.io:9000/rao/HR_comma_sep.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=Q3AM3UQ867SPQQA43P2F%2F20180108%2F%2Fs3%2Faws4_request&X-Amz-Date=20180108T062821Z&X-Amz-Expires=604800&X-Amz-SignedHeaders=host&X-Amz-Signature=6dd111afa8903d8ed81c8575572812a2987cd3241ca9de647770a8fe76b4729f"
s = requests.get(url).content
data = pd.read_csv(io.StringIO(s.decode('utf-8')))
# Display few elements of the data.
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ### Let's see if any data is null

# %%
data.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# sales                    False
# salary                   False
# dtype: bool

# %% [markdown]
# ### Lets see if any data is missing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Data exploration
# Lets rename some of the columns to make them sound more intuitive

# %%
# Renaming certain columns for better readability
data = data.rename(columns={
                     
                        'number_project': 'total_project',
                        'time_spend_company': 'years_at_company',
                        'promotion_last_5years': 'promotion',
                        'sales' : 'department',
                        'left' : 'turnover'
                        })

# %% [markdown]
# Let's check the number of records in the data
# As you can see there are 15000 records with a total of 10 features each

# %%
data.shape
# Out:
# (14999, 10)

# %% [markdown]
# checking the data type of each features

# %%
data.dtypes
# Out:
# satisfaction_level      float64
# last_evaluation         float64
# total_project             int64
# average_montly_hours      int64
# years_at_company          int64
# Work_accident             int64
# turnover                  int64
# promotion                 int64
# department               object
# salary                   object
# dtype: object

# %% [markdown]
# The fields in the dataset include:
#
# 1.   Employee satisfaction level, scaling 0 to 1
# 2.   Last evaluation, scaling 0 to 1
# 3.   Number of projects
# 4.   Average monthly hours
# 5.   Time spent at the company in years
# 6.   Whether they have had a work accident
# 7.   Whether they have had a promotion in the last 5 years
# 8.   Sales (which actually means job function).
# 9.   Salary — low, medium or high
# 10.  Whether the employee has left

# %% [markdown]
# Let's checkout the turnover percentage.
# As you can see 24% employees left and the rest 76% stayed

# %%
turnover_rate = data.turnover.value_counts() / len(data)
turnover_rate
# Out:
# 0    0.761917
# 1    0.238083
# Name: turnover, dtype: float64

# %% [markdown]
# Let's do a summary of aggregated data for people who stayed and those who left and see if it reveals anything.
#
# - The mean satisfaction for employees who left is low.
# - The last evaluation score mean for both categorie of employee are very close. This sort of tells us that there's a high chance lot of highly evaluated employees might be leaving or poorly evaluated employees are being retained.
# - The average working hours mean too is close to each other, this suggest that there's more to just than rigorious working hours for employee turnouts.
# - But the promotion mean is 4 times more for the employees who stayed. This also might mean that people who get promoted are less likely to leave the comopany and this could be a strategy to retain your best employees.

# %%
summary = data.groupby('turnover')
summary.mean()
# Out:
#           satisfaction_level  last_evaluation  total_project  \
# turnover
# 0                   0.666810         0.715473       3.786664
# 1                   0.440098         0.718113       3.855503
#
#           average_montly_hours  years_at_company  Work_accident  promotion
# turnover
# 0                   199.060203          3.380032       0.175009   0.026251
# 1                   207.419210          3.876505       0.047326   0.005321

# %% [markdown]
# Let's get some more statical summary on the data

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  total_project  \
# count        14999.000000     14999.000000   14999.000000
# mean             0.612834         0.716102       3.803054
# std              0.248631         0.171169       1.232592
# min              0.090000         0.360000       2.000000
# 25%              0.440000         0.560000       3.000000
# 50%              0.640000         0.720000       4.000000
# 75%              0.820000         0.870000       5.000000
# max              1.000000         1.000000       7.000000
#
#        average_montly_hours  years_at_company  Work_accident      turnover  \
# count          14999.000000      14999.000000   14999.000000  14999.000000
# mean             201.050337          3.498233       0.144610      0.238083
# std               49.943099          1.460136       0.351719      0.425924
# min               96.000000          2.000000       0.000000      0.000000
# ...

# %% [markdown]
# # Data Visualization
# ## Let's perform some visulation for few stats on the data to understand it bit more.
# - The sales team followed by technical and support consitutes the major chunk of the employees.

# %%
fig, axs = plt.subplots(ncols=1,figsize=(12,6))
g = sns.countplot(data["department"], ax=axs)
plt.setp(g.get_xticklabels(), rotation=45)
plt.tight_layout()
plt.show()
plt.gcf().clear()

# %% [markdown]
# ### Plot of no.of.employees within the three salary range
# - Most of the employees fall in medium or least salary range.

# %%
fig, axs = plt.subplots(ncols=1,figsize=(12,6))
g = sns.countplot(data["salary"], ax=axs)
plt.tight_layout()
plt.show()
plt.gcf().clear()

# %% [markdown]
# # Turnover VS other features
# ### In our quest to find the most contributing features for employee turn over let's find the correction of turnover with other features and then plot them to see whether there's a clear trend.

# %% [markdown]
# ##Coorelation

# %% [markdown]
# `Turnover VS Experience`
# - We see that the employees between 3-5 years experience tend to leave the company.

# %%
sns.barplot(x = 'years_at_company', y = 'turnover', data = data)
sns.plt.title('Turnover VS experience')
# Out:
# Text(0.5,1,'Turnover VS experience')

# %% [markdown]
# ###Turnover VS Number of projects
#
# - Its very clear that employees with less number of projects or the ones with too many projects leave the company.
# - This suggests the employees who are under worked and who are overworked tend to leave the company.
# - Just with this plot we can clearly see that the total number projects is an very important factor towards employee turonout.i
# - What's interesting is that there is 100% turn over w.r.t the employees with 7 projects.

# %%
sns.barplot(x = 'total_project', y = 'turnover', data = data)
sns.plt.title('Number of projects VS Turnover')
# Out:
# Text(0.5,1,'Number of projects VS Turnover')

# %% [markdown]
# ###Turnover Vs Last evaluation
# - The graphs show a clear trend, ones with poor or great last_evaluation tend to leave the company.

# %%
fig, axs = plt.subplots(ncols=1,figsize=(12,6))
data['evaluation_bin'] = pd.qcut(data['last_evaluation'], 10)
sns.barplot(x='evaluation_bin', y='turnover', data=data)
sns.plt.title('last_evaluation VS Turnover')

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %% [markdown]
# ### Turnover vs Satisfaction

# %%
fig, axs = plt.subplots(ncols=1,figsize=(12,6))
data['evaluation_bin'] = pd.qcut(data['satisfaction_level'], 10)
sns.barplot(x='evaluation_bin', y='turnover', data=data)
sns.plt.title('satisfaction VS Turnover')

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %% [markdown]
# #Feature selection
# Firstly we need to identify the most important features for employee turnover. We'll be the some of the classifiers in the next section not for training purposes, but just for understanding which are the most important features that influences employee turnover. Here are the techniques we'll be using for feature selection.
#
# - Corelation heatmap
# - Random Forest Classifier
# - XGBoost Classifier
# - Decision Trees (they reveal much more than that top features)

# %%
df = data.rename(columns={'satisfaction_level': 'satisfaction', 
                        'last_evaluation': 'evaluation',
                        'total_project': 'projectCount',
                        'average_montly_hours': 'averageMonthlyHours',
                        'years_at_company': 'yearsAtCompany',
                        'Work_accident': 'workAccident',
                        'promotion': 'promotion',
                        'department' : 'department',
                        'turnover' : 'turnover'
                        })

df.corr()
# Out:
#                      satisfaction  evaluation  projectCount  \
# satisfaction             1.000000    0.105021     -0.142970
# evaluation               0.105021    1.000000      0.349333
# projectCount            -0.142970    0.349333      1.000000
# averageMonthlyHours     -0.020048    0.339742      0.417211
# yearsAtCompany          -0.100866    0.131591      0.196786
# workAccident             0.058697   -0.007104     -0.004741
# turnover                -0.388375    0.006567      0.023787
# promotion                0.025605   -0.008684     -0.006064
#
#                      averageMonthlyHours  yearsAtCompany  workAccident  \
# satisfaction                   -0.020048       -0.100866      0.058697
# evaluation                      0.339742        0.131591     -0.007104
# projectCount                    0.417211        0.196786     -0.004741
# averageMonthlyHours             1.000000        0.127755     -0.010143
# ...

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True)

plt.title('Correlation between different fearures')
# Out:
# Text(0.5,1,'Correlation between different fearures')

# %% [markdown]
# The corelation heap map shows average monthly hour feature is highly corelated to number of projects (obviously) and the evaluation, due to this high coorelation this feature can be dropped while training with the classifiers in the next section.

# %% [markdown]
# ##Preparing the data for training

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import numpy as np
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,6)

                    
# Renaming certain columns for better readability

df = data.drop(['evaluation_bin','average_montly_hours'],axis=1)

# Convert these variables into categorical variables.
df["department"] = df["department"].astype('category').cat.codes
df["salary"] = df["salary"].astype('category').cat.codes

# Create train and test splits
target_name = 'turnover'
X = df.drop('turnover', axis=1)

# obtain the target value. Its the employee turnover.
y = df[target_name]
# Split the data into test and training set.
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.15, random_state=123, stratify=y)

# %% [markdown]
# ##Random Forest Classifier for feature selection

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, learning_curve
from sklearn.cross_validation import StratifiedKFold

RFC = RandomForestClassifier()

kfold = StratifiedKFold(y_train,n_folds=10,random_state=2)


cv_results = cross_val_score(RFC,X_train, y_train, cv=kfold, scoring="accuracy")

cv_results.mean()

RFC.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
indices = np.argsort(RFC.feature_importances_)[::-1]

train_features = X_train.columns

print(train_features)
print(indices)

fig = plt.figure(figsize=(7, 10))
g = sns.barplot(y=train_features[indices],x = RFC.feature_importances_[indices] , orient='h')
g.set_xlabel("Relative importance",fontsize=12)
g.set_ylabel("Features",fontsize=12)
g.tick_params(labelsize=9)
g.set_title("Random Forest classifier feature importance")



plt.show()
plt.gcf().clear()
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'total_project',
#        'years_at_company', 'Work_accident', 'promotion', 'department',
#        'salary'],
#       dtype='object')
# [0 2 3 1 6 7 4 5]

# %% [markdown]
# ## XGBoost classifier for feature selection

# %%
# !pip install xgboost
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train, y_train)
# feature importance
print(model.feature_importances_)

indices = np.argsort(model.feature_importances_)[::-1]

print(indices)

train_features = X_train.columns

print(train_features)
print(indices)

fig = plt.figure(figsize=(7, 10))
g = sns.barplot(y=train_features[indices],x = model.feature_importances_[indices] , orient='h')
g.set_xlabel("Relative importance",fontsize=12)
g.set_ylabel("Features",fontsize=12)
g.tick_params(labelsize=9)
g.set_title("XGBoost classifier feature importance")



plt.show()
plt.gcf().clear()
# Out:
# ...
# [0.32023576 0.20825148 0.16699411 0.21218075 0.02946955 0.
#  0.01964637 0.043222  ]
# [0 3 1 2 7 4 6 5]
# Index(['satisfaction_level', 'last_evaluation', 'total_project',
#        'years_at_company', 'Work_accident', 'promotion', 'department',
#        'salary'],
#       dtype='object')
# [0 3 1 2 7 4 6 5]

# %% [markdown]
# ##Decision Tree clasifier
# Now that we know the most important features let's run the DT classifier with depth of 3 and visualize the tree which will answer very critical questions employee turnover.

# %%
dtree = tree.DecisionTreeClassifier(max_depth=3)
dtree = dtree.fit(X_train,y_train)

## plot the importances ##
importances = dtree.feature_importances_
feat_names = df.drop(['turnover'],axis=1).columns


indices = np.argsort(importances)[::-1]
plt.figure(figsize=(12,6))
plt.title("Feature importances by DecisionTreeClassifier")
plt.bar(range(len(indices)), importances[indices], color='lightblue',  align="center")
plt.step(range(len(indices)), np.cumsum(importances[indices]), where='mid', label='Cumulative')
plt.xticks(range(len(indices)), feat_names[indices], rotation='vertical',fontsize=14)
plt.xlim([-1, len(indices)])
plt.show()

# !pip install graphviz
# !apt-get install -y graphviz
# !pip install pydotplus

from sklearn.tree import export_graphviz
import graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()

export_graphviz(dtree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names=X_train.columns)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  

graph.set_lwidth(100)
graph.set_lheight(100)
Image(graph.create_png())

#export_graphviz(dtree, out_file="mytree.dot")
#with open("mytree.dot") as f:
#    dot_graph = f.read()
#graphviz.Source(dot_graph)
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.38.0-16ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# ...

# %%
sns.lmplot(x='satisfaction', y='projectCount', data=df,
           fit_reg=False, # No regression line
           hue='turnover')

# %%
data_stay = df[df["turnover"]==0]
data_left = df[df["turnover"]==1]

# %%
sns.lmplot(x='satisfaction', y='yearsAtCompany', data=df,
           fit_reg=False, # No regression line
           hue='turnover')

# %%
sns.lmplot(x='projectCount', y='evaluation', data=df,
           fit_reg=False, # No regression line
           hue='turnover')

# %%
sns.lmplot(x='evaluation', y='yearsAtCompany', data=df,
           fit_reg=False, # No regression line
           hue='turnover')

# %% [markdown]
# We clearly see 3 red clusters in the visualization of satisfaction vs evaluation (see below). We can separate these clusters out using K-means clustering with 3 clusters and then analysing 3 of these groups.
#
# - Performing but unsatisfied. The left most red cluster corresponds to employees who performed well but were really unsatisfied and left the company. Why is this happening? The company is supposed to maintain the interests of well performing employees.
# - Not performing Not satisfied. The middle red cluster corresponds to employees who are not performing well and not happy too and they've left the company.
# - Performing and satisfied. Here is the most alarming cluster, the right-most red cluster on the top. These are well performing and satisfied employees who have left the company. It would very interesting to know why.

# %%
sns.lmplot(x='satisfaction', y='evaluation', data=df,
           fit_reg=False, # No regression line
           hue='turnover')

# %% [markdown]
# ## K means clustering
# Let's use K-means clustering on the data of people who left the company, since we saw a clear grouping in employees who left the company in the satisfacation vs evaluation scatter plot, let's use these features to separate out the clusters and perform further analysis on each one of them.

# %%
from sklearn.cluster import KMeans

# Obtain the data for the employees who've left the company.
data_left = df[df["turnover"]==1]

data_stayed = df[df["turnover"]==0]

print(data_left.shape)

kmeans = KMeans(n_clusters=3,random_state=2)
kmeans.fit(data_left[["satisfaction","evaluation"]])
# Out:
# (3571, 11)
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=2, tol=0.0001, verbose=0)

# %%
kmeans_colors = ['red' if c == 0 else 'orange' if c == 2 else 'blue' for c in kmeans.labels_]

fig = plt.figure(figsize=(10, 7))
plt.scatter(x="satisfaction",y="evaluation", data=data_left,
            alpha=0.25,color = kmeans_colors)
plt.xlabel("Satisfaction level")
plt.ylabel("Last evaluation")

clusters_center_x = kmeans.cluster_centers_[:,0]
clusters_center_y = kmeans.cluster_centers_[:,1]

print('cluster center 1: ', (clusters_center_x[0], clusters_center_y[0]))
print('cluster center 2: ', (clusters_center_x[1], clusters_center_y[1]))
print('cluster center 3: ', (clusters_center_x[2], clusters_center_y[2]))
plt.scatter(x = clusters_center_x, y = clusters_center_y, color="black",marker="X",s=100)
plt.title("Clustering of the employed who left by Kmeans")

plt.show()
# Out:
# cluster center 1:  (0.8085158648925284, 0.9117093142272266)
# cluster center 2:  (0.4101454545454546, 0.5169818181818187)
# cluster center 3:  (0.11115466101694843, 0.8693008474576276)

# %% [markdown]
# Again, here are the 3 groups from the clusters.
# - Performing Unhappy (yellow) == Successfull but unhappy employees (top left)
# - Performing Happy (red) == Successfull and happy employees (top right)
# - Non-performing Unhappy (blue) == Unsuccessfull and unhappy employees (bottom center)

# %%
performing_satisfied_left = data_left[kmeans.labels_ == 0]
nonperforming_unsatisfied_left = data_left[kmeans.labels_ == 1]
performing_unsatisfied_left = data_left[kmeans.labels_ == 2]

print("Employees left: ")
print("Performing Happy: ",performing_satisfied_left.shape)
print("Non-performing Unhappy: ",nonperforming_unsatisfied_left.shape)
print("Performing UnHappy: ",performing_unsatisfied_left.shape)
# Out:
# Employees left:
# Performing Happy:  (977, 11)
# Non-performing Unhappy:  (1650, 11)
# Performing UnHappy:  (944, 11)

# %% [markdown]
# ## Sneak peak
# It's disastrous to see that 977 of well performing and happy employees left and 944 of well performing employees who were satisfied and left the company. A Radar chart on average features of employees who stayed and employees from each of three cluster who left should help us why the critical reasons for employee turnover.
#
# Couldn't find a library to draw Radar chart. Pulled in an implementation found online.

# %%
# Code to draw Radar chart.
def _scale_data(data, ranges):
    (x1, x2) = ranges[0]
    d = data[0]
    return [(d - y1) / (y2 - y1) * (x2 - x1) + x1 for d, (y1, y2) in zip(data, ranges)]

  
class RadarChart():
    def __init__(self, fig, variables, ranges, n_ordinate_levels = 6):
        angles = np.arange(0, 360, 360./len(variables))

        axes = [fig.add_axes([0.1,0.1,0.8,0.8],polar = True, 
        label = "axes{}".format(i)) for i in range(len(variables))]
        _, text = axes[0].set_thetagrids(angles, labels = variables)
        
        for txt, angle in zip(text, angles):
            txt.set_rotation(angle - 90)
        
        for ax in axes[1:]:
            ax.patch.set_visible(False)
            ax.xaxis.set_visible(False)
            ax.grid("off")
        
        for i, ax in enumerate(axes):
            grid = np.linspace(*ranges[i],num = n_ordinate_levels)
            grid_label = [""]+["{:.1f}".format(x) for x in grid[1:]]
            ax.set_rgrids(grid, labels = grid_label, angle = angles[i])
            ax.set_ylim(*ranges[i])
        
        self.angle = np.deg2rad(np.r_[angles, angles[0]])
        self.ranges = ranges
        self.ax = axes[0]

    def plot(self, data, *args, **kw):
        sdata = _scale_data(data, self.ranges)
        self.ax.plot(self.angle, np.r_[sdata, sdata[0]], *args, **kw)

    def fill(self, data, *args, **kw):
        sdata = _scale_data(data, self.ranges)
        self.ax.fill(self.angle, np.r_[sdata, sdata[0]], *args, **kw)

    def legend(self, *args, **kw):
        self.ax.legend(*args, **kw)

# %%
df["salary"] = df["salary"].astype('category').cat.codes
data_stayed["salary"] = data_stayed["salary"].astype('category').cat.codes
performing_unsatisfied_left["salary"] = performing_unsatisfied_left["salary"].astype('category').cat.codes
performing_satisfied_left["salary"] = performing_satisfied_left["salary"].astype('category').cat.codes
nonperforming_unsatisfied_left["salary"] = nonperforming_unsatisfied_left["salary"].astype('category').cat.codes




attributes = ['satisfaction','evaluation','projectCount','averageMonthlyHours','yearsAtCompany','salary']
ranges = [[1e-2, df[attr].max()] for attr in attributes]


fig = plt.figure(figsize=(8, 8))



stayed_mean = data_stayed[attributes].mean().values.reshape(1,-1)
performing_unsatisfied_left_mean = performing_unsatisfied_left[attributes].mean().values.reshape(1,-1)
performing_satisfied_left_mean = performing_satisfied_left[attributes].mean().values.reshape(1,-1)
nonPerforming_unsatisfied_left_mean = nonperforming_unsatisfied_left[attributes].mean().values.reshape(1,-1)


radar_data = np.concatenate((np.array(stayed_mean), np.array(performing_satisfied_left_mean), 
                      np.array(performing_unsatisfied_left_mean), np.array(nonPerforming_unsatisfied_left_mean)),axis=0)


colors = ["green","red","blue","orange"]
left_types = ["Stayed","Performing-Satisfied-Left", "Performing-Unsatisfied-Left", "NonPerforming-Unsatisfied-Left"]

fig = plt.figure(figsize=(17, 17))
radar = RadarChart(fig, attributes, ranges)
for data, color, left_type in zip(radar_data, colors, left_types):
    radar.plot(np.array(data), color = color, label = left_type, linewidth=2.0)
    radar.fill(data, alpha = 0.1, color = color)
    radar.legend(loc = 1, fontsize = 'small')
plt.title('Stats of employees who stayed and left')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Mean salary of employees who stayed:  1.347742387119356
# Mean salary of performing but unsatisfied employees who left the company:  1.3665254237288136
# ...

# %% [markdown]
# #Radar graph interpretation
# - Radar graph shows that the mean salary is the same for all cluster of employees. this clearly tells that the well performing employees needs hike.
# - Its clear why a large section of well performing employees are unsatisfied and they leave the  company. The blue part in the radar graph indicates that these employees work way too many projects and thus spend far too many hours at office and gets paid the same and thus unsatisfied though they perform well. It's clear that they might under lot of stress at work and their load has to reduced to improves the chances of retaining them.
# - As you can see in the red, highly performing and satisfied employee who leave the company tend to spend more number of hours at office on few projects and also they tend to stay longer in the company.

# %% [markdown]
# # Prediction
# ## What we have seen so far all happened in the past, which you cannot undo. However, if you can predict the future, you can do something about it. Making data actionable — that’s the true value of predictive analytics.
# ## Let's build a neural network classifier to predict the probability of an employee leaving the company.
